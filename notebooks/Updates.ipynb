# %% [markdown]
# # Updating `alphafold_strube`
# ---

# %%
# !date
# Out:
# Tue Feb  7 14:34:35 +03 2023

# %% [markdown]
# AF version `2.3.1` is out, and I need to update the code in `alphafold_strube`. The last commit from deepmind is:
#
# ![image.png](attachment:557b7460-a061-4869-aaaa-dba352a4665d.png)

# %% [markdown]
# It seems that when I updated to `v2.2.2` I did a pull request.

# %% [markdown]
# I cannot `sync fork` from the website, so I will try to merge it from the CL.

# %% [markdown]
# First add the remote from deepmind as `upstream`

# %% [raw]
# ~/Documents/py/aroldlab/alphafold_strube  main ?4 ················································································ env 
# ❯ git remote add upstream git@github.com:deepmind/alphafold.git
#
#  ~/Documents/py/aroldlab/alphafold_strube  main ?4 ················································································ env 
# ❯ git remote -v
# origin	git@github.com:strubelab/alphafold.git (fetch)
# origin	git@github.com:strubelab/alphafold.git (push)
# upstream	git@github.com:deepmind/alphafold.git (fetch)
# upstream	git@github.com:deepmind/alphafold.git (push)

# %% [markdown]
# Create `update` branch, fetch remote and merge

# %% [raw]
#  ~/Documents/py/aroldlab/alphafold_strube  main ?4 ················································································ env 
# ❯ git branch update
#
#  ~/Documents/py/aroldlab/alphafold_strube  main ?4 ················································································ env 
# ❯ git checkout update
# Switched to branch 'update'
#
#  ~/Documents/py/aroldlab/alphafold_strube  update ?4 ·············································································· env 
# ❯ git fetch upstream
# remote: Enumerating objects: 230, done.
# remote: Counting objects: 100% (163/163), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 230 (delta 89), reused 102 (delta 73), pack-reused 67
# Receiving objects: 100% (230/230), 10.31 MiB | 1.84 MiB/s, done.
# Resolving deltas: 100% (113/113), completed with 15 local objects.
# From github.com:deepmind/alphafold
#  * [new branch]      main       -> upstream/main
#  * [new tag]         v2.1.2     -> v2.1.2
#  * [new tag]         v2.2.0     -> v2.2.0
#  * [new tag]         v2.2.1     -> v2.2.1
#  * [new tag]         v2.2.2     -> v2.2.2
#  * [new tag]         v2.2.3     -> v2.2.3
#  * [new tag]         v2.2.4     -> v2.2.4
#  * [new tag]         v2.3.0     -> v2.3.0
#  * [new tag]         v2.3.1     -> v2.3.1
#
#  ~/Documents/py/aroldlab/alphafold_strube  update ?4 ········································································· 8s  env 
# ❯ git merge upstream/main
# Auto-merging alphafold/data/pipeline.py
# CONFLICT (content): Merge conflict in alphafold/data/pipeline.py
# Auto-merging requirements.txt
# CONFLICT (content): Merge conflict in requirements.txt
# Auto-merging run_alphafold.py
# CONFLICT (content): Merge conflict in run_alphafold.py
# CONFLICT (modify/delete): setup.py deleted in HEAD and modified in upstream/main.  Version upstream/main of setup.py left in tree.
# Automatic merge failed; fix conflicts and then commit the result.

# %% [markdown]
# Resolved conflicts with vscode

# %% [markdown]
# Made modifications for the new parameter to choose how many models to relax.

# %% [markdown]
# # Updating `alphafold_strube`
# ---

# %%
# !date
# Out:
# Wed Nov 22 21:43:48 +03 2023

# %% [markdown]
# AF version `2.3.2` is out, and I need to update the code in `alphafold_strube`. The last commit from deepmind is:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# It seems that when I updated to `v2.2.2` I did a pull request.

# %% [markdown]
# I cannot `sync fork` from the website, so I will try to merge it from the CL.

# %% [markdown]
# First add the remote from deepmind as `upstream`

# %% [raw]
#  ~/Documents/py/aroldlab/alphafold_strube  main ?2 ··················································· miniconda3 
# ❯ git remote add upstream https://github.com/google-deepmind/alphafold.git
#
#  ~/Documents/py/aroldlab/alphafold_strube  main ?2 ··················································· miniconda3 
# ❯ git remote -v
# origin	git@github.com:strubelab/alphafold.git (fetch)
# origin	git@github.com:strubelab/alphafold.git (push)
# upstream	https://github.com/google-deepmind/alphafold.git (fetch)
# upstream	https://github.com/google-deepmind/alphafold.git (push)

# %% [markdown]
# Create `update` branch, fetch remote and merge

# %% [raw]
#  ~/Documents/py/aroldlab/alphafold_strube  main ?2 ··················································· miniconda3 
# ❯ git branch update
#
#  ~/Documents/py/aroldlab/alphafold_strube  main ?2 ··················································· miniconda3 
# ❯ git checkout update
# Switched to branch 'update'
#
#  ~/Documents/py/aroldlab/alphafold_strube  update ?2 ················································· miniconda3 
# ❯ git fetch upstream
# remote: Enumerating objects: 168, done.
# remote: Counting objects: 100% (156/156), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 168 (delta 86), reused 86 (delta 61), pack-reused 12
# Receiving objects: 100% (168/168), 303.00 KiB | 1.21 MiB/s, done.
# Resolving deltas: 100% (89/89), completed with 13 local objects.
# From https://github.com/google-deepmind/alphafold
#  * [new branch]      main       -> upstream/main
#  * [new tag]         v2.3.2     -> v2.3.2
#
#  ~/Documents/py/aroldlab/alphafold_strube  update ?2 ················································· miniconda3 
# ❯ git merge upstream/main
# Auto-merging requirements.txt
# CONFLICT (content): Merge conflict in requirements.txt
# Auto-merging run_alphafold.py
# CONFLICT (content): Merge conflict in run_alphafold.py
# CONFLICT (modify/delete): setup.py deleted in HEAD and modified in upstream/main.  Version upstream/main of setup.py left in tree.
# Automatic merge failed; fix conflicts and then commit the result.

# %% [markdown]
# Resolved conflicts with vscode. Added setup.py and then deleted it in a subsequent commit.

# %% [markdown]
# I modified the `environment.yml` file and `requirements.txt` to be able to install the entire thing and run it without loading the ibex module. It works!
